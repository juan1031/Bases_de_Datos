# %% [markdown]
# # Concexión Python-MySQL

# %% [markdown]
# ## Requisitos

# %% [markdown]
# Para conectar MySQL a Workbench, debes seguir varios pasos y asegurarte de que cumples con ciertos requisitos:
#
# Descarga e Instalación:
#
# * Descarga MySQL Workbench desde la página oficial de MySQL.
# * Elige la versión adecuada para tu sistema operativo.
# * Sigue los pasos de instalación que se muestran durante el proceso​ (https://mysqlya.com.ar/tecnologia/requisitos-mysql-workbench/)

# %% [markdown]
# ### Para usuarios Linux Ubuntu:
#
# Pueden hacer el proceso desde el terminal guiados de este video: https://youtu.be/KM2y_BeDxGg?si=55n2Q24u59Ml1xmf

# %% [markdown]
# - Al momento de conseguir esta instalación, si te aparece algun error al darle click a a base de datos en mi caso en el cuadro donde dice *Local instance 3306*, ahí deberias ingresar contraseña. Si te aparece errores es posible que sea que no le hayas dado los permisos requeridos

# %% [markdown]
# ![Captura desde 2023-11-08 07-35-58.png](<attachment:Captura desde 2023-11-08 07-35-58.png>)

# %% [markdown]
# - El siguiente paso seria crear una base de datos dentro de nuestro servidor, le das al servidor, entras con tu contraseña y así queda.

# %% [markdown]
# ![Captura desde 2023-11-08 07-46-13.png](<attachment:Captura desde 2023-11-08 07-46-13.png>)

# %% [markdown]
# Ya en la salida se creo la base de datos **dbmysql**

# %% [markdown]
# ## Pasos de Conexión en python

# %%
# !pip install mysql-connector-python  # Empezamos descargando la libreria para la conexión
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 9.0 MB/s eta 0:00:00:00:0100:01
# ...

# %% [markdown]
# ### Importamos librerias

# %%
import mysql.connector

# %% [markdown]
# ### Proceso de conexión

# %%
conexion = mysql.connector.connect(user='root', 
                                   password='1234', 
                                   host='localhost', 
                                   database='bdmysql', 
                                   port='3306')

# %%
print(conexion) # Observamos el objeto creado por la conexión
